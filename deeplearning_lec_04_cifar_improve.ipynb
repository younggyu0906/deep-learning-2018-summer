# %%
import matplotlib.pyplot as plt
import numpy as np

x0 = [float(x/10) for x in range(1, 11)]
x1 = [float(x/10) for x in range(10, 0, -1)]
y = [-(x*np.log(x) + x1[i]*np.log(x1[i])) for i, x in enumerate(x0)]

plt.plot(x0, y)
plt.show()
